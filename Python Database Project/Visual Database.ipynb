# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data_df = pd.read_csv('dnd_monsters.csv', sep=',')

# %%
data_df.keys()
# Out:
# Index(['name', 'url', 'cr', 'type', 'size', 'ac', 'hp', 'speed', 'align',
#        'legendary', 'source', 'str', 'dex', 'con', 'int', 'wis', 'cha'],
#       dtype='object')

# %%
print(data_df)
# Out:
#                   name                                                url  \
# 0            aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...
# 1              abjurer                                                NaN
# 2              aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 3      abominable-yeti                                                NaN
# 4             acererak                                                NaN
# ..                 ...                                                ...
# 757  yuan-ti-pureblood  https://www.aidedd.org/dnd/monstres.php?vo=yua...
# 758            zaratan                                                NaN
# 759             zariel  https://www.aidedd.org/dnd/monstres.php?vo=zariel
# 760             zombie  https://www.aidedd.org/dnd/monstres.php?vo=zombie
# 761           zuggtmoy                                                NaN
#
#       cr                  type        size  ac   hp speed          align  \
# ...

# %%
display(data_df.head(762))
# Out:
#                   name                                                url  \
# 0            aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...
# 1              abjurer                                                NaN
# 2              aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 3      abominable-yeti                                                NaN
# 4             acererak                                                NaN
# ..                 ...                                                ...
# 757  yuan-ti-pureblood  https://www.aidedd.org/dnd/monstres.php?vo=yua...
# 758            zaratan                                                NaN
# 759             zariel  https://www.aidedd.org/dnd/monstres.php?vo=zariel
# 760             zombie  https://www.aidedd.org/dnd/monstres.php?vo=zombie
# 761           zuggtmoy                                                NaN
#
#       cr                  type        size  ac   hp speed          align  \
# ...

# %%
print(data_df.name.to_string(index=False))
# Out:
#                    aarakocra
#                      abjurer
#                      aboleth
#              abominable-yeti
#                     acererak
#                      acolyte
#           adult-black-dragon
#         adult-blue-dracolich
#            adult-blue-dragon
#           adult-brass-dragon
#          adult-bronze-dragon
#          adult-copper-dragon
#            adult-gold-dragon
#           adult-green-dragon
#                adult-kruthik
#                  adult-oblex
#             adult-red-dragon
#          adult-silver-dragon
#           adult-white-dragon
#                air-elemental
#       air-elemental-myrmidon
#         albino-dwarf-warrior
#                       aldani
#                       alhoon
#                     alkilith
#                        allip
#                   allosaurus
#                 ambush-drake
#                       amnizu
#         ancient-black-dragon
#          ancient-blue-dragon
#         ancient-brass-dragon
# ...

# %%
#Each and every cretures name, listed in alphabetical order

# %%
print(data_df.type.to_string(index=False))
# Out:
#                humanoid (aarakocra)
#                 humanoid (any race)
#                          aberration
#                         monstrosity
#                              undead
#                 humanoid (any race)
#                              dragon
#                              undead
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                         monstrosity
#                                ooze
#                              dragon
#                              dragon
#                              dragon
#                           elemental
#                           elemental
#                    humanoid (dwarf)
#                         monstrosity
#                              undead
#                       fiend (demon)
#                              undead
# ...

# %%
#Each and every cretures type, listed in the order they should be in regards to the list above this one.

# %%
data_df.head(20)
# Out:
#                     name                                                url  \
# 0              aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...
# 1                abjurer                                                NaN
# 2                aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 3        abominable-yeti                                                NaN
# 4               acererak                                                NaN
# 5                acolyte  https://www.aidedd.org/dnd/monstres.php?vo=aco...
# 6     adult-black-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 7   adult-blue-dracolich                                                NaN
# 8      adult-blue-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 9     adult-brass-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# 10   adult-bronze-dragon  https://www.aidedd.org/dnd/monstres.php?vo=adu...
# ...

# %%
data_df['type'].value_counts().plot(kind='pie')
plt.title="Entity Types"
fig = plt.figure(figsize=(10, 7))

# %%
#there are genuinely that many classes of "things that exist" within DnD 5e.
#I'm afraid i don't know how to make this look neater, there was nothing i could find
#in matplotlib and seaborn that worked.

# %%
sns.scatterplot(data_df)
# Out:
# <Axes: >

# %%
#And this is a scatter graph that tells us absolutely nothing 
#other than the hp value can be quite varied amongst all of the monsters

# %%
sns.set_style("whitegrid")
plt.title="Type"
sns.histplot(data_df, x="type", color='#ff6347', edgecolor='#ff7f50', shrink=0.85, multiple="stack")
plt.subplots_adjust(right=20)
plt.subplots_adjust(bottom=0.01)

# %%
#so instead, heres a large bar graph showing the exact number of each type of creature. You'll just have to zoom in a little

# %%
#Anyway, onwards to the viewable data and the total number of monsters that can be categorized:

# %%
sns.set_style("whitegrid")
plt.title="Challenge Ratings"
sns.histplot(data_df, x="cr", color='#4169e1', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.05)

# %%
data_df['cr'].value_counts().plot(kind='pie')
plt.title="Challenge Ratings"
fig = plt.figure(figsize=(10, 7))

# %%
#the above tables shows the total number of monsters at each level of "cr" (also known as challenge rating)
#i am still unsure why this table was laid out the way it was, as you can see.

# %%
sns.set_style("whitegrid")
plt.title="Sizes"
sns.histplot(data_df, x="size", color='#dc143c', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=1.5)
plt.subplots_adjust(bottom=0.18)

# %%
data_df['size'].value_counts().plot(kind='pie')
plt.title="Entity Sizes"
fig = plt.figure(figsize=(10, 7))

# %%
#the above tables shows the total amount of monsters/beings that belong to each size.
#medium also being human sized should give you a rough idea on the other categories size.

# %%
sns.set_style("whitegrid")
plt.title="Armour Class"
sns.histplot(data_df, x="ac", color='#9932cc', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=1.5)
plt.subplots_adjust(bottom=0.05)

# %%
#the above table shows the monsters grouped up into groups of equal levels of ac (Armour Class)
#I believe that the large spike is for all the creatures with an ac of 12 (including all of the player character species).

# %%
sns.set_style("whitegrid")
plt.title="Speed"
sns.histplot(data_df, x="speed", color='#e9967a', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=0.75)
plt.subplots_adjust(bottom=0.05)

# %%
#the above table shows the total number of monsters who can traverse their surroundings in an alternative way (I.e; not walking/running).
#Flying being the most common was unsurprising. the number of things that can be fly and swim naturally was a surprise though.

# %%
sns.set_style("whitegrid")
plt.title="Alignment"
sns.histplot(data_df, x="align", color='#483d8b', edgecolor='#ff7f50', shrink=0.85, multiple="stack")
plt.subplots_adjust(right=5.75)
plt.subplots_adjust(bottom=0.00)

# %%
data_df['align'].value_counts().plot(kind='pie')
plt.title="Alignments"
fig = plt.figure(figsize=(10, 7))

# %%
#the above table shows the monsters grouped up into groups of each different alignments.
#I apologise if you cannot read each segments name, i couldn't figure out how to insert the names into each bar, or how to make them vertical.

# %%
sns.set_style("whitegrid")
plt.title="Legends"
sns.histplot(data_df, x="legendary", color='#ffefd5', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=0.5)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters that classify as Legendary monsters.
#considering the original table has 762 creatures, i think this by itself says more than i can.

# %%
sns.set_style("whitegrid")
plt.title="Strength"
sns.histplot(data_df, x="str", color='#00bfff', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of str (Strength).
#it was interesting to see such a large spike close to the number 20,
#as Strength adds to the creatures attack (if they land a hit).

# %%
sns.set_style("whitegrid")
plt.title="Dexterity"
sns.histplot(data_df, x="dex", color='#1e90ff', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of dex (Dexterity).
#As expected most of the monsters trended to the middle of the pack so as to not be too slow or too fast,
#to stop being a challenge to the players at the table.

# %%
sns.set_style("whitegrid")
plt.title="Constitution"
sns.histplot(data_df, x="con", color='#fff0f5', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of con (Constitution).
#because Constitution affects health values,
#it makes sense that very few ended up on the higher end of the scale.

# %%
sns.set_style("whitegrid")
plt.title="Intelligence"
sns.histplot(data_df, x="int", color='#ba55d3', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of int (Intelligence).
#Intelligence lines up with a creatures ability to think, remember something or reason with,
#which makes the first bar all the funnier to me.

# %%
sns.set_style("whitegrid")
plt.title="Wisdom"
sns.histplot(data_df, x="wis", color='#eee8aa', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of wis (wisdom).
#like with Dex and Con, the layout makes sense to me,
#what doesn't is the two gaps which indicate a lack of monsters who have a wisdom value of:
#11, 14, 18, 23, 24 or 26.

# %%
sns.set_style("whitegrid")
plt.title="Charisma"
sns.histplot(data_df, x="cha", color='#db7093', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of cha (Charisma).
#I find it interesting how there seems to be a gap between the last two bars... 
#there isn't any missing data as far as i can tell.

#Charisma is also how well one can get in/out of situations using the power of speech and believability.

# %%
print(data_df.source.to_string(index=False))
# Out:
#                    Monster Manual (BR)
#               Volo's Guide to Monsters
#                   Monster Manual (SRD)
#                         Monster Manual
#      Adventures (Tomb of Annihilation)
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#                         Monster Manual
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#            Mordenkainen's Tome of Foes
#            Mordenkainen's Tome of Foes
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#                   Monster Manual (SRD)
#            Mordenkainen's Tome of Foes
#      Adventures (Tomb of Annihilation)
#      Adventures (Tomb of Annihilation)
#               Volo's Guide to Monsters
# ...

# %%
#The entire list of each creatues source book in DnD 5e
#A handful of books show up the most often in this list as they are dedicated to adding
#monsters to a campaign or setting at the DM's discretion.

# %%
sns.set_style("whitegrid")
plt.title="Source Books"
sns.histplot(data_df, x="source", color='#db7093', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=10)
plt.subplots_adjust(bottom=0.01)

# %%
#and here it is as a table. For if you were curious on exact numbers.

# %%
data_df['source'].value_counts().plot(kind='pie')
plt.title="Source Books"
fig = plt.figure(figsize=(10, 7))

# %%
#This pie chart serves as a way to see how large each sources contributions are.

# %%
data_df.drop(['url','hp', 'speed', 'align', 'str', 'dex', 'con', 'int', 'wis', 'cha'], axis=1)
# Out:
#                   name   cr                  type        size  ac  legendary  \
# 0            aarakocra  1/4  humanoid (aarakocra)      Medium  12        NaN
# 1              abjurer    9   humanoid (any race)      Medium  12        NaN
# 2              aboleth   10            aberration       Large  17  Legendary
# 3      abominable-yeti    9           monstrosity        Huge  15        NaN
# 4             acererak   23                undead      Medium  21        NaN
# ..                 ...  ...                   ...         ...  ..        ...
# 757  yuan-ti-pureblood    1    humanoid (yuan-ti)      Medium  11        NaN
# 758            zaratan   22             elemental  Gargantuan  21        NaN
# 759             zariel   26         fiend (devil)       Large  21  Legendary
# 760             zombie  1/4                undead      Medium   8        NaN
# 761           zuggtmoy   23         fiend (demon)       Large  18        NaN
#
#                                 source
# ...

# %%
#the first and last 5 creatures with a handful of important stats for Dungeon Masters.

# %%
data_df.describe()
# Out:
#                ac          hp         str         dex         con         int  \
# count  762.000000  762.000000  401.000000  401.000000  401.000000  401.000000
# mean    14.577428   88.129921   15.231920   12.745636   15.147132    8.324190
# std      3.140581   94.822305    6.492964    3.183573    4.383012    5.694264
# min      0.000000    0.000000    1.000000    1.000000    8.000000    1.000000
# 25%     12.000000   22.000000   11.000000   10.000000   12.000000    3.000000
# 50%     14.000000   58.000000   16.000000   13.000000   14.000000    8.000000
# 75%     17.000000  126.000000   19.000000   15.000000   17.000000   12.000000
# max     25.000000  676.000000   30.000000   28.000000   30.000000   26.000000
#
#               wis         cha
# count  401.000000  401.000000
# mean    11.820449   10.097257
# std      3.093167    5.696755
# min      2.000000    1.000000
# 25%     10.000000    6.000000
# 50%     12.000000    9.000000
# 75%     13.000000   14.000000
# ...

# %%
#and finally, the total, maximum, minimum, average and percentile most data points in the dataset.
