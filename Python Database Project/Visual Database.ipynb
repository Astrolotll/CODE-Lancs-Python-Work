# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data_df = pd.read_csv('dnd_monsters.csv', sep=',')

# %%
data_df.keys()
# Out:
# Index(['name', 'url', 'cr', 'type', 'size', 'ac', 'hp', 'speed', 'align',
#        'legendary', 'source', 'str', 'dex', 'con', 'int', 'wis', 'cha'],
#       dtype='object')

# %%
print(data_df)
# Out:
#                   name                                                url  \
# 0            aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...
# 1              abjurer                                                NaN
# 2              aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 3      abominable-yeti                                                NaN
# 4             acererak                                                NaN
# ..                 ...                                                ...
# 757  yuan-ti-pureblood  https://www.aidedd.org/dnd/monstres.php?vo=yua...
# 758            zaratan                                                NaN
# 759             zariel  https://www.aidedd.org/dnd/monstres.php?vo=zariel
# 760             zombie  https://www.aidedd.org/dnd/monstres.php?vo=zombie
# 761           zuggtmoy                                                NaN
#
#       cr                  type        size  ac   hp speed          align  \
# 0    1/4  humanoid (aarakocra)      Medium  12   13   fly   neutral good
# 1      9   humanoid (any race)      Medium  12   84   NaN  any alignment
# 2     10            aberration       Large  17  135  swim    lawful evil
# 3      9           monstrosity        Huge  15  137   NaN   chaotic evil
# 4     23                undead      Medium  21  285   NaN   neutral evil
# ..   ...                   ...         ...  ..  ...   ...            ...
# 757    1    humanoid (yuan-ti)      Medium  11   40   NaN   neutral evil
# 758   22             elemental  Gargantuan  21  307  swim        neutral
# 759   26         fiend (devil)       Large  21  580   fly    lawful evil
# 760  1/4                undead      Medium   8   22   NaN   neutral evil
# 761   23         fiend (demon)       Large  18  304   NaN   chaotic evil
#
#      legendary                             source   str   dex   con   int  \
# 0          NaN                Monster Manual (BR)  10.0  14.0  10.0  11.0
# 1          NaN           Volo's Guide to Monsters   NaN   NaN   NaN   NaN
# 2    Legendary               Monster Manual (SRD)  21.0   9.0  15.0  18.0
# 3          NaN                     Monster Manual   NaN   NaN   NaN   NaN
# 4          NaN  Adventures (Tomb of Annihilation)   NaN   NaN   NaN   NaN
# ..         ...                                ...   ...   ...   ...   ...
# 757        NaN                Monster Manual (BR)  11.0  12.0  11.0  13.0
# 758        NaN        Mordenkainen's Tome of Foes   NaN   NaN   NaN   NaN
# 759  Legendary        Mordenkainen's Tome of Foes  27.0  24.0  28.0  26.0
# 760        NaN               Monster Manual (SRD)  13.0   6.0  16.0   3.0
# 761        NaN        Mordenkainen's Tome of Foes   NaN   NaN   NaN   NaN
#
#       wis   cha
# 0    12.0  11.0
# 1     NaN   NaN
# 2    15.0  18.0
# 3     NaN   NaN
# 4     NaN   NaN
# ..    ...   ...
# 757  12.0  14.0
# 758   NaN   NaN
# 759  27.0  30.0
# 760   6.0   5.0
# 761   NaN   NaN
#
# [762 rows x 17 columns]

# %%
display(data_df.head(762))
# Out:
#                   name                                                url  \
# 0            aarakocra  https://www.aidedd.org/dnd/monstres.php?vo=aar...
# 1              abjurer                                                NaN
# 2              aboleth  https://www.aidedd.org/dnd/monstres.php?vo=abo...
# 3      abominable-yeti                                                NaN
# 4             acererak                                                NaN
# ..                 ...                                                ...
# 757  yuan-ti-pureblood  https://www.aidedd.org/dnd/monstres.php?vo=yua...
# 758            zaratan                                                NaN
# 759             zariel  https://www.aidedd.org/dnd/monstres.php?vo=zariel
# 760             zombie  https://www.aidedd.org/dnd/monstres.php?vo=zombie
# 761           zuggtmoy                                                NaN
#
#       cr                  type        size  ac   hp speed          align  \
# 0    1/4  humanoid (aarakocra)      Medium  12   13   fly   neutral good
# 1      9   humanoid (any race)      Medium  12   84   NaN  any alignment
# 2     10            aberration       Large  17  135  swim    lawful evil
# 3      9           monstrosity        Huge  15  137   NaN   chaotic evil
# 4     23                undead      Medium  21  285   NaN   neutral evil
# ..   ...                   ...         ...  ..  ...   ...            ...
# 757    1    humanoid (yuan-ti)      Medium  11   40   NaN   neutral evil
# 758   22             elemental  Gargantuan  21  307  swim        neutral
# 759   26         fiend (devil)       Large  21  580   fly    lawful evil
# 760  1/4                undead      Medium   8   22   NaN   neutral evil
# 761   23         fiend (demon)       Large  18  304   NaN   chaotic evil
#
#      legendary                             source   str   dex   con   int  \
# 0          NaN                Monster Manual (BR)  10.0  14.0  10.0  11.0
# 1          NaN           Volo's Guide to Monsters   NaN   NaN   NaN   NaN
# 2    Legendary               Monster Manual (SRD)  21.0   9.0  15.0  18.0
# 3          NaN                     Monster Manual   NaN   NaN   NaN   NaN
# 4          NaN  Adventures (Tomb of Annihilation)   NaN   NaN   NaN   NaN
# ..         ...                                ...   ...   ...   ...   ...
# 757        NaN                Monster Manual (BR)  11.0  12.0  11.0  13.0
# 758        NaN        Mordenkainen's Tome of Foes   NaN   NaN   NaN   NaN
# 759  Legendary        Mordenkainen's Tome of Foes  27.0  24.0  28.0  26.0
# 760        NaN               Monster Manual (SRD)  13.0   6.0  16.0   3.0
# 761        NaN        Mordenkainen's Tome of Foes   NaN   NaN   NaN   NaN
#
#       wis   cha
# 0    12.0  11.0
# 1     NaN   NaN
# 2    15.0  18.0
# 3     NaN   NaN
# 4     NaN   NaN
# ..    ...   ...
# 757  12.0  14.0
# 758   NaN   NaN
# 759  27.0  30.0
# 760   6.0   5.0
# 761   NaN   NaN
#
# [762 rows x 17 columns]

# %%
print(data_df.name.to_string(index=False))
# Out:
#                    aarakocra
#                      abjurer
#                      aboleth
#              abominable-yeti
#                     acererak
#                      acolyte
#           adult-black-dragon
#         adult-blue-dracolich
#            adult-blue-dragon
#           adult-brass-dragon
#          adult-bronze-dragon
#          adult-copper-dragon
#            adult-gold-dragon
#           adult-green-dragon
#                adult-kruthik
#                  adult-oblex
#             adult-red-dragon
#          adult-silver-dragon
#           adult-white-dragon
#                air-elemental
#       air-elemental-myrmidon
#         albino-dwarf-warrior
#                       aldani
#                       alhoon
#                     alkilith
#                        allip
#                   allosaurus
#                 ambush-drake
#                       amnizu
#         ancient-black-dragon
#          ancient-blue-dragon
#         ancient-brass-dragon
#        ancient-bronze-dragon
#        ancient-copper-dragon
#          ancient-gold-dragon
#         ancient-green-dragon
#           ancient-red-dragon
#               ancient-shadow
#        ancient-silver-dragon
#         ancient-white-dragon
#                  androsphinx
#               animated-armor
#                       ankheg
#                 ankylosaurus
#                    annis-hag
#                          ape
#            apprentice-wizard
#                   arcanaloth
#                    archdruid
#                       archer
#                     archmage
#                     armanite
#                     assassin
#                assassin-vine
#           astral-dreadnought
#                      atropal
#                      aurochs
#               autumn-eladrin
#               awakened-shrub
#                awakened-tree
#                     axe-beak
#                         azer
#                        babau
#                       baboon
#                       badger
#                         bael
#                   balhannoth
#                        balor
#                   banderhobb
#                       bandit
#               bandit-captain
#                      banshee
#                     baphomet
#                 barbed-devil
#                         bard
#                     barghest
#                     barlgura
#                     basilisk
#                          bat
#                bearded-devil
#                        behir
#                     beholder
#              beholder-zombie
#                    belaphoss
#                    berbalang
#                    berserker
#                    bheur-hag
#                black-abishai
#                   black-bear
#        black-dragon-wyrmling
#       black-gauntlet-of-bane
#                black-pudding
#                   blackguard
#                    blink-dog
#                   blood-hawk
#                 blue-abishai
#         blue-dragon-wyrmling
#                   blue-slaad
#                         boar
#                        bodak
#                       boggle
#                   bone-devil
#                    bone-naga
#                     boneclaw
#        brass-dragon-wyrmling
#                 brontosaurus
#       bronze-dragon-wyrmling
#                   brown-bear
#                      bugbear
#                bugbear-chief
#                      bulette
#                      bulezau
#                     bullywug
#            cadaver-collector
#                      cambion
#                        camel
#                     canoloth
#              carrion-crawler
#                          cat
#                   catoblepas
#                  cave-fisher
#                      centaur
#                  chain-devil
#                     champion
#                       chasme
#                      chimera
#                      chitine
#                       choker
#                    choldrith
#                        chuul
#                   clay-golem
#                      cloaker
#                  cloud-giant
#      cloud-giant-smiling-one
#                   cockatrice
#                     commoner
#                     conjurer
#            constrictor-snake
#       copper-dragon-wyrmling
#                corpse-flower
#                       couatl
#                          cow
#                         crab
#                     crag-cat
#                  cranium-rat
#                crawling-claw
#                    crocodile
#                 crokek-toeck
#                 cult-fanatic
#                      cultist
#                      cyclops
#                          dao
#                     darkling
#               darkling-elder
#                   darkmantle
#                    death-dog
#                   death-kiss
#                 death-knight
#                  death-slaad
#                 death-tyrant
#        death-s-head-of-bhaal
#                    deathlock
#         deathlock-mastermind
#              deathlock-wight
#       deep-gnome-svirfneblin
#                   deep-scion
#                         deer
#                  deinonychus
#                     demilich
#                   demogorgon
#                        derro
#                 derro-savant
#                         deva
#                    devilroot
#                     devourer
#                   dhergoloth
#                   dimetrodon
#                   dire-troll
#                    dire-wolf
#              displacer-beast
#                      diviner
#                       djinni
#                      dolphin
#                 doppelganger
#                    draegloth
#                  draft-horse
#                dragon-turtle
#                   dragonbait
#                       dretch
#                       drider
#                         drow
#           drow-arachnomancer
#           drow-elite-warrior
#         drow-favored-consort
#           drow-house-captain
#              drow-inquisitor
#                    drow-mage
#           drow-matron-mother
#     drow-priestress-of-lolth
#             drow-shadowblade
#                        druid
#                        dryad
#                      duergar
#               duergar-despot
#          duergar-kavalrachni
#          duergar-mind-master
#            duergar-soulblade
#          duergar-stone-guard
#              duergar-warlord
#              duergar-xarrorn
#                     duodrone
#                  dust-mephit
#                       dybbuk
#                        eagle
#              earth-elemental
#     earth-elemental-myrmidon
#                        eblis
#                      efreeti
#                      eidolon
#                  elder-brain
#                  elder-oblex
#                elder-tempest
#                     elephant
#                          elk
#                     empyrean
#                    enchanter
#                      erinyes
#                     ettercap
#                        ettin
#                       evoker
#                 expert-lvl-1
#                 expert-lvl-2
#                 expert-lvl-3
#                 expert-lvl-4
#                 expert-lvl-5
#                 expert-lvl-6
#                faerie-dragon
#               female-steeder
#               fire-elemental
#      fire-elemental-myrmidon
#                   fire-giant
#       fire-giant-dreadnought
#                   fire-snake
#     firenewt-warlock-of-imix
#             firenewt-warrior
#                 fist-of-bane
#                  flail-snail
#                   flameskull
#                  flesh-golem
#                        flind
#                       flumph
#                 flying-snake
#                 flying-sword
#                     fomorian
#                 fraz-urb-luu
#                         frog
#                   froghemoth
#                  frost-giant
#  frost-giant-everlasting-one
#             frost-salamander
#                   galeb-duhr
#                     gargoyle
#                    gas-spore
#                        gauth
#                        gazer
#              gelatinous-cube
#                       geryon
#                        ghast
#                        ghost
#                        ghoul
#                    giant-ape
#                 giant-badger
#                    giant-bat
#                   giant-boar
#              giant-centipede
#      giant-constrictor-snake
#                   giant-crab
#              giant-crocodile
#                  giant-eagle
#                    giant-elk
#            giant-fire-beetle
#    giant-four-armed-gargoyle
#                   giant-frog
#                   giant-goat
#                  giant-hyena
#                 giant-lizard
#                giant-octopus
#                    giant-owl
#        giant-poisonous-snake
#                    giant-rat
#               giant-scorpion
#              giant-sea-horse
#                  giant-shark
#                 giant-spider
#                giant-strider
#                   giant-toad
#        giant-two-headed-goat
#                giant-vulture
#                   giant-wasp
#                 giant-weasel
#            giant-wolf-spider
#            gibbering-mouther
#                         giff
#                     girallon
#               githyanki-gish
#          githyanki-kith--rak
#             githyanki-knight
#  githyanki-supreme-commander
#            githyanki-warrior
#             githzerai-anarch
#         githzerai-enlightned
#               githzerai-monk
#              githzerai-zerth
#                     glabrezu
#                    gladiator
#                 gloom-weaver
#                        gnoll
#       gnoll-fang-of-yeenoghu
#           gnoll-flesh-gnawer
#                 gnoll-hunter
#              gnoll-pack-lord
#             gnoll-witherling
#                         goat
#                       goblin
#                  goblin-boss
#         gold-dragon-wyrmling
#                       gorgon
#                     goristro
#                    gray-ooze
#                  gray-render
#                   gray-slaad
#                      graz-zt
#                green-abishai
#        green-dragon-wyrmling
#                    green-hag
#                  green-slaad
#                        grell
#                        grick
#                  grick-alpha
#                      griffon
#                     grimlock
#                        grung
#          grung-elite-warrior
#               grung-wildling
#                        guard
#                  guard-drake
#                guardian-naga
#                   gynosphinx
#          halaster-blackcloak
#                    half-ogre
#      half-red-dragon-veteran
#                        harpy
#                         hawk
#                   hell-hound
#              hellfire-engine
#                     hellwasp
#                helmed-horror
#                       hezrou
#                   hill-giant
#                   hippogriff
#                    hobgoblin
#            hobgoblin-captain
#         hobgoblin-devastator
#        hobgoblin-iron-shadow
#            hobgoblin-warlord
#                   homunculus
#                  hook-horror
#                 horned-devil
#                       howler
#                 hulking-crab
#                 hunter-shark
#                      hutijin
#                        hydra
#                    hydroloth
#                        hyena
#                    ice-devil
#                   ice-mephit
#                     ice-toad
#                  illusionist
#                         imix
#                          imp
#           intellect-devourer
#            invisible-stalker
#                   iron-cobra
#                  iron-consul
#                   iron-golem
#                       jackal
#                   jackalwere
#                       jaculi
#              jarlaxle-baenre
#                      juiblex
#                      kamadan
#                        kenku
#                       ki-rin
#                 killer-whale
#                       knight
#                       kobold
#          kobold-dragonshield
#              kobold-inventor
#        kobold-scale-sorcerer
#                       korred
#                       kraken
#                kraken-priest
#            kruthik-hive-lord
#                      kuo-toa
#           kuo-toa-archpriest
#                 kuo-toa-whip
#            laeral-silverhand
#                        lamia
#                       lemure
#                    leucrotta
#                    leviathan
#                         lich
#                         lion
#                       lizard
#            lizard-king-queen
#                   lizardfolk
#            lizardfolk-shaman
#                         mage
#                 magma-mephit
#                       magmin
#                 male-steeder
#                      mammoth
#                        manes
#                     manshoon
#                    manticore
#                      mantrap
#                        marid
#                     marilith
#           martial-arts-adept
#                        marut
#              master-of-souls
#                 master-thief
#                      mastiff
#                     maurezhi
#                    maw-demon
#                       meazel
#                       medusa
#                     meenlock
#                      merfolk
#                     merregon
#                  merrenoloth
#                       merrow
#                    mezzoloth
#                        mimic
#                  mind-flayer
#                  mindwitness
#                     minotaur
#            minotaur-skeleton
#                       moloch
#                     molydeus
#                    monodrone
#                      morkoth
#           mouth-of-grolantor
#                   mud-mephit
#                         mule
#            mummified-warrior
#                        mummy
#                   mummy-lord
#                myconid-adult
#            myconid-sovereign
#               myconid-sprout
#                      nabassu
#                        nagpa
#                   nalfeshnee
#                     narzugon
#                  necromancer
#          necromite-of-myrkul
#                needle-blight
#                        neogi
#              neogi-hatchling
#                 neogi-master
#                    neothelid
#                  night-blade
#                    night-hag
#                    nightmare
#                  nightwalker
#                       nilbog
#                        noble
#                       nothic
#                    nupperibo
#                     nycaloth
#                  oblex-spawn
#                  ochre-jelly
#                      octopus
#                         ogre
#           ogre-battering-ram
#           ogre-bolt-launcher
#             ogre-chain-brute
#                  ogre-howdah
#                  ogre-zombie
#                     ogremoch
#                     oinoloth
#                      olhydra
#                          oni
#                          orc
#         orc-blade-of-ilneval
#           orc-claw-of-luthic
#           orc-eye-of-gruumsh
#          orc-hand-of-yurtrus
#     orc-red-fang-of-shargaas
#                orc-war-chief
#                        orcus
#                         orog
#                       orthon
#                       otyugh
#                          owl
#                      owlbear
#                      panther
#                      pegasus
#                   pentadrone
#                      peryton
#                 phase-spider
#                      phoenix
#                      piercer
#                    pit-fiend
#                        pixie
#                     planetar
#                 plesiosaurus
#              poisonous-snake
#                   polar-bear
#                         pony
#                       priest
#                 pseudodragon
#                    pterafolk
#                   pteranodon
#                  purple-worm
#              purple-wormling
#                     quadrone
#                     quaggoth
#       quaggoth-spore-servant
#                       quasit
#               quetzalcoatlus
#                    quickling
#                      quipper
#                     rakshasa
#                          rat
#                        raven
#              reaper-of-bhaal
#                  red-abishai
#          red-dragon-wyrmling
#                    red-slaad
#                       redcap
#               reef-manta-ray
#                   reef-shark
#                     remorhaz
#                    retriever
#                     revenant
#                   rhinoceros
#                 riding-horse
#                          roc
#                        roper
#                    rot-troll
#            rug-of-smothering
#                 rust-monster
#                    rutterkin
#          saber-toothed-tiger
#                     sahuagin
#               sahuagin-baron
#           sahuagin-priestess
#                   salamander
#                        satyr
#                    scarecrow
#                     scorpion
#                        scout
#                      sea-hag
#                    sea-horse
#                    sea-spawn
#                       shadow
#                shadow-dancer
#                 shadow-demon
#               shadow-mastiff
#              shambling-mound
#              shield-guardian
#                     shoosuva
#                     shrieker
#                      sibriex
#       silver-dragon-wyrmling
#                     skeleton
#                        skulk
#       skull-lasher-of-myrkul
#                   skull-lord
#                slaad-tadpole
#           slithering-tracker
#                 smoke-mephit
#                        solar
#                  soul-monger
#               spawn-of-kyuss
#                    spectator
#                      specter
#     spellcaster-healer-lvl-1
#     spellcaster-healer-lvl-2
#     spellcaster-healer-lvl-3
#     spellcaster-healer-lvl-4
#     spellcaster-healer-lvl-5
#     spellcaster-healer-lvl-6
#       spellcaster-mage-lvl-1
#       spellcaster-mage-lvl-2
#       spellcaster-mage-lvl-3
#       spellcaster-mage-lvl-4
#       spellcaster-mage-lvl-5
#       spellcaster-mage-lvl-6
#                       spider
#                 spined-devil
#                  spirit-naga
#                 spirit-troll
#               spring-eladrin
#                       sprite
#                          spy
#              star-spawn-grue
#              star-spawn-hulk
#        star-spawn-larva-mage
#           star-spawn-mangler
#              star-spawn-seer
#                 steam-mephit
#               steel-predator
#                  stegosaurus
#                       stirge
#                 stone-cursed
#                  stone-giant
#      stone-giant-dreamwalker
#                  stone-golem
#             stone-juggernaut
#                  storm-giant
#      storm-giant-quintessent
#          strahd-von-zarovich
#                   su-monster
#                     succubus
#               summer-eladrin
#                swarm-of-bats
#        swarm-of-cranium-rats
#             swarm-of-insects
#    swarm-of-poisonous-snakes
#            swarm-of-quippers
#                swarm-of-rats
#              swarm-of-ravens
#           swarm-of-rot-grubs
#                 swashbuckler
#       sword-wraith-commander
#         sword-wraith-warrior
#                tabaxi-hunter
#              tabaxi-minstrel
#                     tanarukk
#                    tarrasque
#                    the-angry
#                   the-hungry
#                   the-lonely
#                     the-lost
#                 the-wretched
#                       thorny
#                   thri-kreen
#                         thug
#                       tiamat
#                        tiger
#                    titivilus
#                    tlincalli
#                       tortle
#                 tortle-druid
#                   transmuter
#                      trapper
#                       treant
#             tri-flower-frond
#               tribal-warrior
#                  triceratops
#                     tridrone
#                   troglodyte
#                        troll
#                  twig-blight
#            tyrannosaurus-rex
#                    ulitharid
#                    ultroloth
#                   umber-hulk
#                      unicorn
#              uthgardt-shaman
#                 vajra-safahr
#                      vampire
#                vampire-spawn
#                vampiric-mist
#                   vargouille
#                    vegepygmy
#              vegepygmy-chief
#                 velociraptor
#             venerable-shadow
#                  venom-troll
#                      veteran
#                  vine-blight
#                violet-fungus
#                        vrock
#                      vulture
#                   war-priest
#                     warhorse
#            warhorse-skeleton
#       warlock-of-the-archfey
#         warlock-of-the-fiend
# warlock-of-the-great-old-one
#                      warlord
#                warrior-lvl-1
#                warrior-lvl-2
#                warrior-lvl-3
#                warrior-lvl-4
#                warrior-lvl-5
#                warrior-lvl-6
#                   wastrilith
#              water-elemental
#     water-elemental-myrmidon
#                  water-weird
#                       weasel
#                     werebear
#                     wereboar
#                      wererat
#                    weretiger
#                     werewolf
#                white-abishai
#        white-dragon-wyrmling
#                        wight
#                     wild-dog
#               wild-dog-alpha
#                 will-o--wisp
#                winged-kobold
#               winter-eladrin
#                  winter-wolf
#                         wolf
#                    wood-woad
#                         worg
#                       wraith
#                       wyvern
#                         xorn
#                        xvart
#    xvart-warlock-of-raxivort
#                    yagnoloth
#                    yan-c-bin
#                     yeenoghu
#          yellow-musk-creeper
#           yellow-musk-zombie
#                   yeth-hound
#                         yeti
#                      yochlol
#           young-black-dragon
#            young-blue-dragon
#           young-brass-dragon
#          young-bronze-dragon
#          young-copper-dragon
#            young-gold-dragon
#           young-green-dragon
#                young-kruthik
#             young-red-dragon
#      young-red-shadow-dragon
#               young-remorhaz
#          young-silver-dragon
#           young-white-dragon
#          yuan-ti-abomination
#             yuan-ti-anathema
#           yuan-ti-broodguard
#              yuan-ti-malison
#       yuan-ti-mind-whisperer
#    yuan-ti-nightmare-speaker
#           yuan-ti-pit-master
#            yuan-ti-pureblood
#                      zaratan
#                       zariel
#                       zombie
#                     zuggtmoy

# %%
#Each and every cretures name, listed in alphabetical order

# %%
print(data_df.type.to_string(index=False))
# Out:
#                humanoid (aarakocra)
#                 humanoid (any race)
#                          aberration
#                         monstrosity
#                              undead
#                 humanoid (any race)
#                              dragon
#                              undead
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                         monstrosity
#                                ooze
#                              dragon
#                              dragon
#                              dragon
#                           elemental
#                           elemental
#                    humanoid (dwarf)
#                         monstrosity
#                              undead
#                       fiend (demon)
#                              undead
#                               beast
#                              dragon
#                       fiend (devil)
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              undead
#                              dragon
#                              dragon
#                         monstrosity
#                           construct
#                         monstrosity
#                               beast
#                                 fey
#                               beast
#                 humanoid (any race)
#                    fiend (yugoloth)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                       fiend (demon)
#                 humanoid (any race)
#                               plant
#                 monstrosity (titan)
#                      undead (titan)
#                               beast
#                           fey (elf)
#                               plant
#                               plant
#                               beast
#                           elemental
#                       fiend (demon)
#                               beast
#                               beast
#                       fiend (devil)
#                          aberration
#                       fiend (demon)
#                         monstrosity
#                 humanoid (any race)
#                 humanoid (any race)
#                              undead
#                       fiend (demon)
#                       fiend (devil)
#                 humanoid (any race)
#                fiend (shapechanger)
#                       fiend (demon)
#                         monstrosity
#                               beast
#                       fiend (devil)
#                         monstrosity
#                          aberration
#                              undead
#                       fiend (demon)
#                          aberration
#                 humanoid (any race)
#                                 fey
#                       fiend (devil)
#                               beast
#                              dragon
#                    humanoid (human)
#                                ooze
#                 humanoid (any race)
#                                 fey
#                               beast
#                       fiend (devil)
#                              dragon
#                          aberration
#                               beast
#                              undead
#                                 fey
#                       fiend (devil)
#                              undead
#                              undead
#                              dragon
#                               beast
#                              dragon
#                               beast
#                humanoid (goblinoid)
#                humanoid (goblinoid)
#                         monstrosity
#                       fiend (demon)
#                 humanoid (bullywug)
#                           construct
#                               fiend
#                               beast
#                    fiend (yugoloth)
#                         monstrosity
#                               beast
#                         monstrosity
#                         monstrosity
#                         monstrosity
#                       fiend (devil)
#                 humanoid (any race)
#                       fiend (demon)
#                         monstrosity
#                         monstrosity
#                          aberration
#                         monstrosity
#                          aberration
#                           construct
#                          aberration
#                               giant
#                 giant (cloud giant)
#                         monstrosity
#                 humanoid (any race)
#                 humanoid (any race)
#                               beast
#                              dragon
#                               plant
#                           celestial
#                               beast
#                               beast
#                               beast
#                               beast
#                              undead
#                               beast
#                       fiend (demon)
#                 humanoid (any race)
#                 humanoid (any race)
#                               giant
#                           elemental
#                                 fey
#                                 fey
#                         monstrosity
#                         monstrosity
#                          aberration
#                              undead
#           aberration (shapechanger)
#                              undead
#                    humanoid (human)
#                              undead
#                              undead
#                              undead
#                    humanoid (gnome)
#             humanoid (shapechanger)
#                               beast
#                               beast
#                              undead
#                       fiend (demon)
#                    humanoid (derro)
#                    humanoid (derro)
#                           celestial
#                               plant
#                               fiend
#                    fiend (yugoloth)
#                               beast
#                               giant
#                               beast
#                         monstrosity
#                 humanoid (any race)
#                           elemental
#                               beast
#          monstrosity (shapechanger)
#                       fiend (demon)
#                               beast
#                              dragon
#                  humanoid (saurial)
#                       fiend (demon)
#                         monstrosity
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                      humanoid (elf)
#                 humanoid (any race)
#                                 fey
#                    humanoid (dwarf)
#                    humanoid (dwarf)
#                    humanoid (dwarf)
#                    humanoid (dwarf)
#                    humanoid (dwarf)
#                    humanoid (dwarf)
#                    humanoid (dwarf)
#                    humanoid (dwarf)
#                           construct
#                           elemental
#                       fiend (demon)
#                               beast
#                           elemental
#                           elemental
#                         monstrosity
#                           elemental
#                              undead
#                          aberration
#                                ooze
#                           elemental
#                               beast
#                               beast
#                   celestial (titan)
#                 humanoid (any race)
#                       fiend (devil)
#                         monstrosity
#                               giant
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                              dragon
#                         monstrosity
#                           elemental
#                           elemental
#                               giant
#                  giant (fire giant)
#                           elemental
#                 humanoid (firenewt)
#                 humanoid (firenewt)
#                    humanoid (human)
#                           elemental
#                              undead
#                           construct
#                    humanoid (gnoll)
#                          aberration
#                               beast
#                           construct
#                               giant
#                       fiend (demon)
#                               beast
#                         monstrosity
#                               giant
#                 giant (frost giant)
#                           elemental
#                           elemental
#                           elemental
#                               plant
#                          aberration
#                          aberration
#                                ooze
#                       fiend (devil)
#                              undead
#                              undead
#                              undead
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                           elemental
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                         monstrosity
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                               beast
#                          aberration
#                            humanoid
#                         monstrosity
#                     humanoid (gith)
#                     humanoid (gith)
#                     humanoid (gith)
#                     humanoid (gith)
#                     humanoid (gith)
#                     humanoid (gith)
#                     humanoid (gith)
#                     humanoid (gith)
#                     humanoid (gith)
#                       fiend (demon)
#                 humanoid (any race)
#                      humanoid (elf)
#                    humanoid (gnoll)
#                       fiend (gnoll)
#                    humanoid (gnoll)
#                    humanoid (gnoll)
#                    humanoid (gnoll)
#                              undead
#                               beast
#                humanoid (goblinoid)
#                humanoid (goblinoid)
#                              dragon
#                         monstrosity
#                       fiend (demon)
#                                ooze
#                         monstrosity
#           aberration (shapechanger)
#         fiend (demon, shapechanger)
#                       fiend (devil)
#                              dragon
#                                 fey
#           aberration (shapechanger)
#                          aberration
#                         monstrosity
#                         monstrosity
#                         monstrosity
#                 humanoid (grimlock)
#                    humanoid (grung)
#                    humanoid (grung)
#                    humanoid (grung)
#                 humanoid (any race)
#                              dragon
#                         monstrosity
#                         monstrosity
#                    humanoid (human)
#                               giant
#                    humanoid (human)
#                         monstrosity
#                               beast
#                               fiend
#                           construct
#                               fiend
#                           construct
#                       fiend (demon)
#                               giant
#                         monstrosity
#                humanoid (goblinoid)
#                humanoid (goblinoid)
#                humanoid (goblinoid)
#                humanoid (goblinoid)
#                humanoid (goblinoid)
#                           construct
#                         monstrosity
#                       fiend (devil)
#                               fiend
#                               beast
#                               beast
#                       fiend (devil)
#                         monstrosity
#                    fiend (yugoloth)
#                               beast
#                       fiend (devil)
#                           elemental
#                         monstrosity
#                 humanoid (any race)
#                           elemental
#         fiend (devil, shapechanger)
#                          aberration
#                           elemental
#                           construct
#                    humanoid (human)
#                           construct
#                               beast
#             humanoid (shapechanger)
#                               beast
#                      humanoid (elf)
#                       fiend (demon)
#                         monstrosity
#                    humanoid (kenku)
#                           celestial
#                               beast
#                 humanoid (any race)
#                   humanoid (kobold)
#                   humanoid (kobold)
#                   humanoid (kobold)
#                   humanoid (kobold)
#                                 fey
#                 monstrosity (titan)
#                 humanoid (any race)
#                         monstrosity
#                  humanoid (kuo-toa)
#                  humanoid (kuo-toa)
#                  humanoid (kuo-toa)
#                    humanoid (human)
#                         monstrosity
#                       fiend (devil)
#                         monstrosity
#                           elemental
#                              undead
#                               beast
#                               beast
#               humanoid (lizardfolk)
#               humanoid (lizardfolk)
#               humanoid (lizardfolk)
#                 humanoid (any race)
#                           elemental
#                           elemental
#                         monstrosity
#                               beast
#                       fiend (demon)
#                    humanoid (human)
#                         monstrosity
#                               plant
#                           elemental
#                       fiend (demon)
#                 humanoid (any race)
#              construct (inevitable)
#                    humanoid (human)
#                 humanoid (any race)
#                               beast
#                       fiend (demon)
#                       fiend (demon)
#                   humanoid (meazel)
#                         monstrosity
#                                 fey
#                  humanoid (merfolk)
#                       fiend (devil)
#                    fiend (yugoloth)
#                         monstrosity
#                    fiend (yugoloth)
#          monstrosity (shapechanger)
#                          aberration
#                          aberration
#                         monstrosity
#                              undead
#                       fiend (devil)
#                       fiend (demon)
#                           construct
#                          aberration
#                  giant (hill giant)
#                           elemental
#                               beast
#                              undead
#                              undead
#                              undead
#                               plant
#                               plant
#                               plant
#                       fiend (demon)
#                    humanoid (nagpa)
#                       fiend (demon)
#                       fiend (devil)
#                 humanoid (any race)
#                    humanoid (human)
#                               plant
#                          aberration
#                          aberration
#                          aberration
#                          aberration
#                    humanoid (human)
#                               fiend
#                               fiend
#                              undead
#                humanoid (goblinoid)
#                 humanoid (any race)
#                          aberration
#                       fiend (devil)
#                    fiend (yugoloth)
#                                ooze
#                                ooze
#                               beast
#                               giant
#                               giant
#                               giant
#                               giant
#                               giant
#                              undead
#                           elemental
#                    fiend (yugoloth)
#                           elemental
#                               giant
#                      humanoid (orc)
#                      humanoid (orc)
#                      humanoid (orc)
#                      humanoid (orc)
#                      humanoid (orc)
#                      humanoid (orc)
#                      humanoid (orc)
#                       fiend (demon)
#                      humanoid (orc)
#                       fiend (devil)
#                          aberration
#                               beast
#                         monstrosity
#                               beast
#                           celestial
#                           construct
#                         monstrosity
#                         monstrosity
#                           elemental
#                         monstrosity
#                       fiend (devil)
#                                 fey
#                           celestial
#                               beast
#                               beast
#                               beast
#                               beast
#                 humanoid (any race)
#                              dragon
#                         monstrosity
#                               beast
#                         monstrosity
#                         monstrosity
#                           construct
#                 humanoid (quaggoth)
#                               plant
#         fiend (demon, shapechanger)
#                               beast
#                                 fey
#                               beast
#                               fiend
#                               beast
#                               beast
#                    humanoid (human)
#                       fiend (devil)
#                              dragon
#                          aberration
#                                 fey
#                               beast
#                               beast
#                         monstrosity
#                           construct
#                              undead
#                               beast
#                               beast
#                         monstrosity
#                         monstrosity
#                               giant
#                           construct
#                         monstrosity
#                       fiend (demon)
#                               beast
#                 humanoid (sahuagin)
#                 humanoid (sahuagin)
#                 humanoid (sahuagin)
#                           elemental
#                                 fey
#                           construct
#                               beast
#                 humanoid (any race)
#                                 fey
#                               beast
#                            humanoid
#                              undead
#                      humanoid (elf)
#                       fiend (demon)
#                         monstrosity
#                               plant
#                           construct
#                       fiend (demon)
#                               plant
#                       fiend (demon)
#                              dragon
#                              undead
#                            humanoid
#                    humanoid (human)
#                              undead
#                          aberration
#                                ooze
#                           elemental
#                           celestial
#                      humanoid (elf)
#                              undead
#                          aberration
#                              undead
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                               beast
#                       fiend (devil)
#                         monstrosity
#                               giant
#                           fey (elf)
#                                 fey
#                 humanoid (any race)
#                          aberration
#                          aberration
#                          aberration
#                          aberration
#                          aberration
#                           elemental
#                           construct
#                               beast
#                               beast
#                           construct
#                               giant
#                 giant (stone giant)
#                           construct
#                           construct
#                               giant
#                 giant (storm giant)
#               undead (shapechanger)
#                         monstrosity
#                fiend (shapechanger)
#                           fey (elf)
#                swarm of Tiny beasts
#                swarm of Tiny beasts
#                swarm of Tiny beasts
#                swarm of Tiny beasts
#                swarm of Tiny beasts
#                swarm of Tiny beasts
#                swarm of Tiny beasts
#                swarm of Tiny beasts
#                 humanoid (any race)
#                              undead
#                              undead
#                   humanoid (tabaxi)
#                   humanoid (tabaxi)
#                  fiend (demon, orc)
#                 monstrosity (titan)
#                         monstrosity
#                         monstrosity
#                         monstrosity
#                         monstrosity
#                         monstrosity
#                               plant
#               humanoid (thri-kreen)
#                 humanoid (any race)
#                               fiend
#                               beast
#                       fiend (devil)
#                         monstrosity
#                   humanoid (tortle)
#                   humanoid (tortle)
#                 humanoid (any race)
#                         monstrosity
#                               plant
#                               plant
#                 humanoid (any race)
#                               beast
#                           construct
#               humanoid (troglodyte)
#                               giant
#                               plant
#                               beast
#                          aberration
#                    fiend (yugoloth)
#                         monstrosity
#                           celestial
#                    humanoid (human)
#                    humanoid (human)
#               undead (shapechanger)
#                              undead
#                              undead
#                               fiend
#                               plant
#                               plant
#                               beast
#                              undead
#                               giant
#                 humanoid (any race)
#                               plant
#                               plant
#                       fiend (demon)
#                               beast
#                 humanoid (any race)
#                               beast
#                              undead
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                 humanoid (any race)
#                       fiend (demon)
#                           elemental
#                           elemental
#                           elemental
#                               beast
#      humanoid (human, shapechanger)
#      humanoid (human, shapechanger)
#      humanoid (human, shapechanger)
#      humanoid (human, shapechanger)
#      humanoid (human, shapechanger)
#                       fiend (devil)
#                              dragon
#                              undead
#                               beast
#                               beast
#                              undead
#                   humanoid (kobold)
#                           fey (elf)
#                         monstrosity
#                               beast
#                               plant
#                         monstrosity
#                              undead
#                              dragon
#                           elemental
#                    humanoid (xvart)
#                    humanoid (xvart)
#                    fiend (yugoloth)
#                           elemental
#                       fiend (demon)
#                               plant
#                              undead
#                                 fey
#                         monstrosity
#         fiend (demon, shapechanger)
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                              dragon
#                         monstrosity
#                              dragon
#                              dragon
#                         monstrosity
#                              dragon
#                              dragon
# monstrosity (shapechanger, yuan-ti)
# monstrosity (shapechanger, yuan-ti)
#                  humanoid (yuan-ti)
# monstrosity (shapechanger, yuan-ti)
# monstrosity (shapechanger, yuan-ti)
# monstrosity (shapechanger, yuan-ti)
# monstrosity (shapechanger, yuan-ti)
#                  humanoid (yuan-ti)
#                           elemental
#                       fiend (devil)
#                              undead
#                       fiend (demon)

# %%
#Each and every cretures type, listed in the order they should be in regards to the list above this one.

# %%
data_df['type'].value_counts().plot(kind='pie')
plt.title="Entity Types"
fig = plt.figure(figsize=(10, 7))

# %%
#there are genuinely that many classes of "things that exist" within DnD 5e.
#I'm afraid i don't know how to make this look neater, there was nothing i could find
#in matplotlib and seaborn that worked.

# %%
sns.set_style("whitegrid")
plt.title="Type"
sns.histplot(data_df, x="type", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=20)
plt.subplots_adjust(bottom=0.01)

# %%
#so instead, heres a large bar graph showing the exact number of each type of creature. You'll jst have to zoom in a little

# %%
#Anyway, onwards to the viewable data and the total number of monsters that can be categorized:

# %%
sns.set_style("whitegrid")
plt.title="Challenge Ratings"
sns.histplot(data_df, x="cr", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.05)

# %%
#the above table shows the total number of monsters at each level of "cr" (also known as challenge rating)
#i am still unsure why this table was laid out the way it was, as you can see.

# %%
sns.set_style("whitegrid")
plt.title="Sizes"
sns.histplot(data_df, x="size", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=1.5)
plt.subplots_adjust(bottom=0.18)

# %%
#the above table shows the total amount of monsters/beings that belong to each size.
#medium also being human sized should give you a rough idea on the other categories size.

# %%
sns.set_style("whitegrid")
plt.title="Armour Class"
sns.histplot(data_df, x="ac", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=1.5)
plt.subplots_adjust(bottom=0.05)

# %%
#the above table shows the monsters grouped up into groups of equal levels of ac (Armour Class)
#I believe that the large spike is for all the creatures with an ac of 12 (including all of the player character species).

# %%
sns.set_style("whitegrid")
plt.title="Speed"
sns.histplot(data_df, x="speed", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=0.75)
plt.subplots_adjust(bottom=0.05)

# %%
#the above table shows the total number of monsters who can traverse their surroundings in an alternative way (I.e; not walking/running).
#Flying being the most common was unsurprising. the number of things that can be fly and swim naturally was a surprise though.

# %%
sns.set_style("whitegrid")
plt.title="Alignment"
sns.histplot(data_df, x="align", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=5.75)
plt.subplots_adjust(bottom=0.00)

# %%
#the above table shows the monsters grouped up into groups of each different alignments.
#I apologise if you cannot read each segments name, i couldn't figure out how to insert the names into each bar, or how to make them vertical.

# %%
sns.set_style("whitegrid")
plt.title="Legends"
sns.histplot(data_df, x="legendary", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=0.5)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters that classify as Legendary monsters.
#considering the original table has 762 creatures, i think this by itself says more han i can.

# %%
sns.set_style("whitegrid")
plt.title="Strength"
sns.histplot(data_df, x="str", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of str (Strength)
#it was interesting to see such a large spike close to the number 20, as Strength adds to the creatures attack (if they land a hit).

# %%
sns.set_style("whitegrid")
plt.title="Dexterity"
sns.histplot(data_df, x="dex", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of dex (Dexterity)

# %%
sns.set_style("whitegrid")
plt.title="Constitution"
sns.histplot(data_df, x="con", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of con (Constitution)

# %%
sns.set_style("whitegrid")
plt.title="Intelligence"
sns.histplot(data_df, x="int", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of int (Intelligence)

# %%
sns.set_style("whitegrid")
plt.title="Wisdom"
sns.histplot(data_df, x="wis", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of wis (wisdom)

# %%
sns.set_style("whitegrid")
plt.title="Charisma"
sns.histplot(data_df, x="cha", color='#3cb371', edgecolor='#ff7f50', shrink=0.85)
plt.subplots_adjust(right=2)
plt.subplots_adjust(bottom=0.01)

# %%
#the above table shows the monsters grouped up into groups of equal levels of cha (Charisma)
#I find it interesting how there seems to be a gap between the last two bars... there isn't any missing data as far as i can tell.

# %%
#now for any
